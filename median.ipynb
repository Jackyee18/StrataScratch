# %% [markdown]
# # Median Salary
#
# Find the median employee salary of each department.
# Output the department name along with the corresponding salary rounded to the nearest whole dollar.

# %%
import pandas as pd
import numpy as np
q=pd.read_csv('employee.csv')
q
# Out:
#     id first_name last_name  age sex employee_title  department  salary  \
# 0    5        Max    George   26   M          Sales       Sales    1300
# 1   13      Katty      Bond   56   F        Manager  Management  150000
# 2   11    Richerd      Gear   57   M        Manager  Management  250000
# 3   10   Jennifer      Dion   34   F          Sales       Sales    1000
# 4   19     George       Joe   50   M        Manager  Management  100000
# 5   18      Laila      Mark   26   F          Sales       Sales    1000
# 6   20     Sarrah     Bicky   31   F   Senior Sales       Sales    2000
# 7   21      Suzan       Lee   34   F          Sales       Sales    1300
# 8   22      Mandy      John   31   F          Sales       Sales    1300
# 9   23    Britney     Berry   45   F          Sales       Sales    1200
# 10  25       Jack      Mick   29   M          Sales       Sales    1300
# 11  26        Ben       Ten   43   M          Sales       Sales    1300
# ...

# %%
q[q.salary==q.salary.median()]
# Out:
#     id first_name last_name  age sex employee_title department  salary  \
# 0    5        Max    George   26   M          Sales      Sales    1300
# 7   21      Suzan       Lee   34   F          Sales      Sales    1300
# 8   22      Mandy      John   31   F          Sales      Sales    1300
# 10  25       Jack      Mick   29   M          Sales      Sales    1300
# 11  26        Ben       Ten   43   M          Sales      Sales    1300
# 13  29    Antoney      Adam   34   M          Sales      Sales    1300
# 23  24       Adam    Morris   30   M          Sales      Sales    1300
#
#     target  bonus                email        city               address  \
# 0      200    150      Max@company.com  California  2638 Richards Avenue
# 7      200    150    Suzan@company.com     Florida    1275 Monroe Avenue
# 8      200    150    Mandy@company.com     Florida  2510 Maryland Avenue
# 10     200    100     Jack@company.com      Hawaii  3762 Stratford Drive
# ...
