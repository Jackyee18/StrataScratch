# %% [markdown]
# # Host Popularity Rental Prices
#
#
# You’re given a table of rental property searches by users. The table consists of search results and outputs host information for searchers. Find the minimum, average, maximum rental prices for each host’s popularity rating. The host’s popularity rating is defined as below:
#
# - 0 reviews: New
# - 1 to 5 reviews: Rising
# - 6 to 15 reviews: Trending Up
# - 16 to 40 reviews: Popular
# - more than 40 reviews: Hot
#
#
# Tip: The id column in the table refers to the search ID. You'll need to create your own host_id by concating price, room_type, host_since, zipcode, and number_of_reviews.
#
#
# Output host popularity rating and their minimum, average and maximum rental prices.

# %%
import pandas as pd
import numpy as np
q=pd.read_csv('airbnb_host_searches.csv')
q
# Out:
#            id   price property_type        room_type  \
# 0     8284881  621.46         House  Entire home/apt
# 1     8284882  621.46         House  Entire home/apt
# 2     9479348  598.90     Apartment  Entire home/apt
# 3     8596057  420.47         House     Private room
# 4    11525500  478.75     Apartment  Entire home/apt
# ..        ...     ...           ...              ...
# 162   3380585  436.94     Apartment     Private room
# 163  10770929  561.68     Apartment  Entire home/apt
# 164   7347593  504.34         House     Private room
# 165  11157369  409.43     Apartment     Private room
# 166  16354537  478.75     Apartment     Private room
#
#                                              amenities  accommodates  \
# 0    {TV,"Cable TV",Internet,"Wireless Internet","A...             8
# 1    {TV,"Cable TV",Internet,"Wireless Internet","A...             8
# 2    {"Wireless Internet","Air conditioning",Kitche...             7
# ...

# %%
q['popularity_rating']='New'

# %%
q.loc[(q.number_of_reviews>=1)&(q.number_of_reviews<=5),'popularity_rating']='Rising'

# %%
q.loc[(q.number_of_reviews>=6)&(q.number_of_reviews<=15),'popularity_rating']='Trending Up'

# %%
q.loc[(q.number_of_reviews>=16)&(q.number_of_reviews<=40),'popularity_rating']='Popular'

# %%
q.loc[(q.number_of_reviews>40),'popularity_rating']='Hot'

# %%
q.groupby('popularity_rating').agg({'price':['min','mean','max']})
# Out:
#                     price
#                       min        mean     max
# popularity_rating
# Hot                340.12  467.467391  633.51
# New                313.55  516.671622  741.76
# Popular            270.81  472.815000  667.83
# Rising             355.53  506.646905  717.01
# Trending Up        361.09  476.277179  685.65
