# %% [markdown]
# # Find the variance and the standard deviation of scores that have grade A
#
# Find the variance of scores that have grade A using the formula AVG((X_i - mean_x) ^ 2).
# Output the result along with the corresponding standard deviation.

# %%
import pandas as pd
import numpy as np
q=pd.read_csv('los_angeles_restaurant_health_inspections.csv')
q
# Out:
#     erial_number   activity_date             facility_name  score grade  \
# 0      DAQHRSETQ   6/8/2017 0:00           MARGARITAS CAFE     93     A
# 1      DA2GQRJOS   3/7/2017 0:00            LAS MOLENDERAS     97     A
# 2      DAMQTA46T  3/22/2016 0:00          SANDRA'S TAMALES     93     A
# 3      DAXMBTIRZ  2/12/2018 0:00            CAFE GRATITUDE     97     A
# 4      DAK8TBMS0  9/10/2015 0:00                THE WAFFLE     90     A
# ..           ...             ...                       ...    ...   ...
# 294    DAFM1YEPX  3/13/2018 0:00  DRINK / QUENCH HOLLYWOOD     94     A
# 295    DAXKTJJXU  2/14/2018 0:00          QWENCH JUICE BAR     90     A
# 296    DA7798LO0  1/16/2018 0:00               PRESTO DELI     97     A
# 297    DALAYS0EE  1/10/2018 0:00                 ANTONIO'S     97     A
# 298    DAL6AQGIQ   1/5/2018 0:00              ROBEKS JUICE     95     A
#
#      service_code service_description employee_id  \
# 0               1  ROUTINE INSPECTION   EE0000006
# 1               1  ROUTINE INSPECTION   EE0000997
# 2               1  ROUTINE INSPECTION   EE0001049
# 3               1  ROUTINE INSPECTION   EE0000828
# 4               1  ROUTINE INSPECTION   EE0000709
# ..            ...                 ...         ...
# 294             1  ROUTINE INSPECTION   EE0000835
# 295             1  ROUTINE INSPECTION   EE0001058
# 296             1  ROUTINE INSPECTION   EE0000684
# 297             1  ROUTINE INSPECTION   EE0000951
# 298             1  ROUTINE INSPECTION   EE0000846
#
#                   facility_address facility_city facility_id facility_state  \
# 0             5026 S CRENSHAW BLVD   LOS ANGELES   FA0023656             CA
# 1               2635 WHITTIER BLVD   LOS ANGELES   FA0160416             CA
# 2               5390 WHITTIER BLVD   LOS ANGELES   FA0171769             CA
# 3    639 N LARCHMONT BLVD STE #102   LOS ANGELES   FA0058921             CA
# 4      6255 W SUNSET BLVD STE #105   LOS ANGELES   FA0051830             CA
# ..                             ...           ...         ...            ...
# 294             6848 W SUNSET BLVD   LOS ANGELES   FA0030817             CA
# 295    201 N LOS ANGELES ST STE 24   LOS ANGELES   FA0030822             CA
# 296             1849 SAWTELLE BLVD   LOS ANGELES   FA0045117             CA
# 297               7470 MELROSE AVE   LOS ANGELES   FA0006521             CA
# 298           1915 N HILLHURST AVE   LOS ANGELES   FA0046628             CA
#
#     facility_zip   owner_id                    owner_name  \
# 0          90043  OW0004133              BAZAN, ASCENCION
# 1          90023  OW0125379             MARISOL FEREGRINO
# 2     90022-4032  OW0178828         SANDRA'S TAMALES INC.
# 3          90004  OW0005704  CAFE GRATITUDE LARCHMONT LLC
# 4          90028  OW0035796               THE WAFFLE, LLC
# ..           ...        ...                           ...
# 294        90028  OW0000115   110 SUNSHINE SMOOTHIES, INC
# 295        90012  OW0000115   110 SUNSHINE SMOOTHIES, INC
# 296        90025  OW0013793                GOODWIN TYRONE
# 297        90046  OW0003489               AXY ENTERPRISES
# 298        90027  OW0000118  110 SUNSHINE SMOOTHIES, INC.
#
#                             pe_description  program_element_pe  \
# 0      RESTAURANT (61-150) SEATS HIGH RISK                1638
# 1        RESTAURANT (0-30) SEATS HIGH RISK                1632
# 2    RESTAURANT (0-30) SEATS MODERATE RISK                1631
# 3      RESTAURANT (61-150) SEATS HIGH RISK                1638
# 4      RESTAURANT (61-150) SEATS HIGH RISK                1638
# ..                                     ...                 ...
# 294  RESTAURANT (0-30) SEATS MODERATE RISK                1631
# 295  RESTAURANT (0-30) SEATS MODERATE RISK                1631
# 296  RESTAURANT (0-30) SEATS MODERATE RISK                1631
# 297    RESTAURANT (151 + ) SEATS HIGH RISK                1641
# 298  RESTAURANT (0-30) SEATS MODERATE RISK                1631
#
#                  program_name program_status  record_id
# 0             MARGARITAS CAFE         ACTIVE  PR0011718
# 1              LAS MOLENDERAS       INACTIVE  PR0148504
# 2            SANDRA'S TAMALES         ACTIVE  PR0164225
# 3              CAFE GRATITUDE         ACTIVE  PR0019854
# 4                  THE WAFFLE         ACTIVE  PR0010922
# ..                        ...            ...        ...
# 294  DRINK / QUENCH HOLLYWOOD         ACTIVE  PR0010536
# 295          QWENCH JUICE BAR         ACTIVE  PR0019841
# 296               PRESTO DELI         ACTIVE  PR0023493
# 297                 ANTONIO'S         ACTIVE  PR0010215
# 298              ROBEKS JUICE         ACTIVE  PR0012195
#
# [299 rows x 20 columns]

# %%
q[q.grade=='A'].score.std()
# Out:
# 3.086304672185509

# %%
q[q.grade=='A'].score.var()
# Out:
# 9.525276529554104
