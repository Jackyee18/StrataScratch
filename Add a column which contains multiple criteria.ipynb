# %% [markdown]
# # Reviews Bins on Reviews Number
#
#
#
# To better understand the effect of the review count on the price of accomodation, categorize the number of reviews into the following groups along with the price.
# - 0 reviews: NO
# - 1 to 5 reviews: FEW
# - 6 to 15 reviews: SOME
# - 16 to 40 reviews: MANY
# - more than 40 reviews: A LOT
#
#
# Output the price and it's categorization. Perform the categorization on accomodation level.

# %%
import pandas as pd
import numpy as np
q=pd.read_csv('airbnb_search_details.csv')
q
# Out:
#            id   price property_type        room_type  \
# 0    12513361  555.68     Apartment  Entire home/apt
# 1     7196412  366.36         Cabin     Private room
# 2    16333776  482.83         House     Private room
# 3     1786412  448.86     Apartment     Private room
# 4    14575777  506.89         Villa     Private room
# ..        ...     ...           ...              ...
# 155  20257960  478.75         House     Private room
# 156   4559312  510.59     Apartment  Entire home/apt
# 157   2165604  368.89     Apartment     Private room
# 158  18385413  409.43     Apartment  Entire home/apt
# 159   9470528  477.91     Apartment  Entire home/apt
#
#                                              amenities  accommodates  \
# 0    {TV,"Wireless Internet","Air conditioning","Sm...             2
# 1    {"Wireless Internet",Kitchen,Washer,Dryer,"Smo...             2
# 2    {TV,"Cable TV",Internet,"Wireless Internet",Ki...             2
# ...

# %%
# syntax to segment and sort data into bins 
q['category1']=pd.cut(q.number_of_reviews,5,labels=['NO','FEW','SMOKE','MANY','A LOT'])

# %%
q['category1'].value_counts()
# Out:
# NO       146
# FEW        6
# SMOKE      5
# A LOT      2
# MANY       1
# Name: category1, dtype: int64

# %%
q[q.category1=='FEW']
# Out:
#            id   price property_type        room_type  \
# 7     6591755  529.33         Villa  Entire home/apt
# 20    7823396  417.44         House     Private room
# 66    5792141  486.75     Apartment  Entire home/apt
# 93   15454112  459.51         House     Private room
# 124   1174876  424.85         House     Private room
# 138  14219018  444.27     Apartment     Private room
#
#                                              amenities  accommodates  \
# 7    {TV,"Cable TV",Internet,"Wireless Internet",Ki...            16
# 20   {TV,"Cable TV","Wireless Internet","Air condit...             2
# 66   {TV,Internet,"Wireless Internet","Air conditio...             4
# 93   {TV,"Cable TV",Internet,"Wireless Internet","A...             2
# 124  {"Wireless Internet","Air conditioning","Pets ...             2
# 138  {TV,"Cable TV",Internet,"Wireless Internet","A...             2
#
#      bathrooms  bed_type cancellation_policy  cleaning_fee  ...  \
# ...

# %%
category3=[]
for i in q.number_of_reviews.values:
    if i == 0:
        category3.append('NO')
    elif i>=1 and i <=5:
        category3.append('FEW')
    elif i>=6 and i<=15:
        category3.append('SOME')
    elif i>=16 and i<=40:
        category3.append('MANY')
    else:
        category3.append('A LOT')

q['category3']=category3

# %%
q['category2']='NO'

# %%
q.loc[(q.number_of_reviews>=1)&(q.number_of_reviews<=5),'category2']='FEW'

# %%
q.loc[(q.number_of_reviews>=6)&(q.number_of_reviews<=15),'category2']='SOME'

# %%
q.loc[(q.number_of_reviews>=16)&(q.number_of_reviews<=40),'category2']='MANY'

# %%
q.loc[(q.number_of_reviews>40),'category2']='A LOT'

# %%
q['category2'].value_counts()
# Out:
# FEW      41
# SOME     39
# NO       35
# MANY     26
# A LOT    19
# Name: category2, dtype: int64

# %%
q.groupby('category2').price.mean().reset_index(name='avg_price').sort_values('avg_price')
# Out:
#   category2   avg_price
# 0     A LOT  464.233158
# 2      MANY  472.815000
# 4      SOME  476.277179
# 1       FEW  503.846585
# 3        NO  515.919714
