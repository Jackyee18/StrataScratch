# %% [markdown]
# # Inspection Scores For Businesses
#
#
#
# Find the median inspection score of each business and output the result along with the business name. Order records based on the inspection score in descending order.
# Try to come up with your own precise median calculation. In Postgres there is percentile_disc function available, however it's only approximation.

# %%
import pandas as pd
import numpy as np
q=pd.read_csv('sf_restaurant_health_violations.csv',encoding='latin-1') # read the table
q
# Out:
#      business_id                   business_name   business_address  \
# 0           5800     John Chin Elementary School    350 Broadway St
# 1          64236       Sutter Pub and Restaurant      700 Sutter St
# 2           1991                SRI THAI CUISINE   4621 LINCOLN Way
# 3           3816  Washington Bakery & Restaurant  733 Washington St
# 4          39119             Brothers Restaurant    4128 GEARY Blvd
# ..           ...                             ...                ...
# 292          500                    Roxanne Cafe      570 Powell St
# 293          500                    Roxanne Cafe      570 Powell St
# 294          500                    Roxanne Cafe      570 Powell St
# 295          500                    Roxanne Cafe      570 Powell St
# 296          500                    Roxanne Cafe      570 Powell St
#
#      business_city business_state  business_postal_code  business_latitude  \
# ...

# %%
q.groupby('business_name').inspection_score.median().reset_index(name='median_score')
# Out:
#                                       business_name  median_score
# 0                        24 Hour Fitness Club, #273          88.0
# 1                            24th and Folsom Eatery           NaN
# 2                       7-Eleven, Store 2366-21389F          85.0
# 3                     95117 Premium Commissary Room          96.0
# 4                                        A La Turca           NaN
# ..                                              ...           ...
# 261                         Wing Lee BBQ Restaurant          78.0
# 262                                   Wing Lum Cafe           NaN
# 263                               YUMMA'S MED GRILL          96.0
# 264  Yerba Buena Tea Co (formerly Tea Smiths of SF)         100.0
# 265                                    Yummy Sticks          81.0
#
# [266 rows x 2 columns]
